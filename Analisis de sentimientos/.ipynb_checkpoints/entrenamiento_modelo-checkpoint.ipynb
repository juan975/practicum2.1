# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, f1_score, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
# Importacion de datos de entrenamiento
df = pd.read_excel('data_entrenada_propia_GP.ods', engine='odf')
df
# Out:
#       Unnamed: 0                                           feedback  codigo  \
# 0         624927  muy bien elaborada, se podría incluir ciertos ...  624927
# 1         543337  La información es ordenada y precisa pero reco...  543337
# 2         614284                                   Excelente aporte  614284
# 3         296130  En la respuesta que le he puesto 3, ha sido po...  296130
# 4         555037                                 Conciso, excelente  555037
# ...          ...                                                ...     ...
# 2995      684953                                          excelente  684953
# 2996      444203  Felicidades estimado/a estudiante, excelente t...  444203
# 2997      666824                           Me gusto su presentación  666824
# 2998      167032  Se entiende en la formulacion de la encuesta q...  167032
# 2999      486468  La infografía cumple con todo lo requerido en ...  486468
#
#      polaridad Unnamed: 4
# 0            P        NaN
# 1            P        NaN
# 2            P        NaN
# 3            N        NaN
# 4            P        NaN
# ...        ...        ...
# 2995         P        NaN
# 2996         P        NaN
# 2997         P        NaN
# 2998         P        NaN
# 2999       NEU        NaN
#
# [3000 rows x 5 columns]

# %%
df2 = pd.read_csv('Dataset_de_Pruebas_Extendido.csv')
df2
# Out:
#                                                feedback polaridad
# 0         La experiencia fue excelente, muy recomendada         P
# 1             Nunca recibí lo que pedí, pésimo servicio         N
# 2                 No tengo nada relevante que mencionar       NEU
# 3                 Definitivamente lo volvería a comprar         P
# 4             El paquete estaba incompleto y defectuoso         N
# ...                                                 ...       ...
# 2996       La experiencia fue regular, ni buena ni mala       NEU
# 2997                   El equipo funciona perfectamente         P
# 2998  La atención fue deficiente y no cumplieron lo ...         N
# 2999              Podría ser mejor, pero no es terrible       NEU
# 3000                                 No la recomendaria         N
#
# [3001 rows x 2 columns]

# %% [markdown]
# # Limpieza de datos

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0       0
# feedback         5
# codigo           0
# polaridad        7
# Unnamed: 4    2792
# dtype: int64

# %%
# Eliminar filas con valores nulos en 'feedback' o 'polaridad'
df = df.dropna(subset=['feedback', 'polaridad'])

# %%
# Verificar que los valores nulos se eliminaron
print(df.isnull().sum())
# Out:
# Unnamed: 0       0
# feedback         0
# codigo           0
# polaridad        0
# Unnamed: 4    2780
# dtype: int64

# %%
# DataFrame solo con las columnas necesarias
df = df[['polaridad', 'feedback']]

# %%
# Revision de la columna 'polaridad'
print(df['polaridad'].value_counts())
# Out:
# polaridad
# P         1780
# N          552
# NEU        330
# NONE       322
# NUE          2
# NEUTRO       1
# NOE          1
# Name: count, dtype: int64

# %%
# Normalizar los nombres de la polaridad
df.loc[(df['polaridad'] == 'NEUTRO') | (df['polaridad'] == 'NUE') | (df['polaridad'] == 'NOE')]
# Out:
#      polaridad                                           feedback
# 68      NEUTRO                                           Muy Bien
# 253        NUE  Hay variedad de plantas que son medicinales de...
# 1331       NOE                                         10 puntos.
# 1446       NUE                                      Muy narrativa

# %%
# Cambiar valores incorrectos
df.loc[:, 'polaridad'] = df['polaridad'].replace({
    'NEUTRO': 'P',
    'NOE': 'NONE',
    'NUE': 'NEU'
})

# %%
# Revision de los cambios en la columna 'polaridad'
print(df['polaridad'].value_counts())
# Out:
# polaridad
# P       1781
# N        552
# NEU      332
# NONE     323
# Name: count, dtype: int64

# %%
df['feedback'] = df['feedback'].astype(str)

# %%
df.head()
# Out:
#   polaridad                                           feedback
# 0         P  muy bien elaborada, se podría incluir ciertos ...
# 1         P  La información es ordenada y precisa pero reco...
# 2         P                                   Excelente aporte
# 3         N  En la respuesta que le he puesto 3, ha sido po...
# 4         P                                 Conciso, excelente

# %%
# Eliminar los datos NONE que no tienen ningun valor
df = df[df['polaridad'] != 'NONE']

# %%
# Concatenar los datasets por filas
df = pd.concat([df, df2], ignore_index=True)

# Mostrar el resultado
df
# Out:
#      polaridad                                           feedback
# 0            P  muy bien elaborada, se podría incluir ciertos ...
# 1            P  La información es ordenada y precisa pero reco...
# 2            P                                   Excelente aporte
# 3            N  En la respuesta que le he puesto 3, ha sido po...
# 4            P                                 Conciso, excelente
# ...        ...                                                ...
# 5661       NEU       La experiencia fue regular, ni buena ni mala
# 5662         P                   El equipo funciona perfectamente
# 5663         N  La atención fue deficiente y no cumplieron lo ...
# 5664       NEU              Podría ser mejor, pero no es terrible
# 5665         N                                 No la recomendaria
#
# [5666 rows x 2 columns]

# %%
df['polaridad'].hist()
# Out:
# <Axes: >

# %%
# Crear codigos para cada polaridad
target_map = {'P': 1, 'N': 0, 'NEU': 2}
df['target'] = df['polaridad'].map(target_map)

# %%
df
# Out:
#      polaridad                                           feedback  target
# 0            P  muy bien elaborada, se podría incluir ciertos ...       1
# 1            P  La información es ordenada y precisa pero reco...       1
# 2            P                                   Excelente aporte       1
# 3            N  En la respuesta que le he puesto 3, ha sido po...       0
# 4            P                                 Conciso, excelente       1
# ...        ...                                                ...     ...
# 5661       NEU       La experiencia fue regular, ni buena ni mala       2
# 5662         P                   El equipo funciona perfectamente       1
# 5663         N  La atención fue deficiente y no cumplieron lo ...       0
# 5664       NEU              Podría ser mejor, pero no es terrible       2
# 5665         N                                 No la recomendaria       0
#
# [5666 rows x 3 columns]

# %% [markdown]
# # Entrenamiento del Modelo

# %%
# Division de datos para entrenamiento y prueba
df_train, df_test = train_test_split(df, test_size=0.4)

# %%
df_train
# Out:
#      polaridad                                           feedback  target
# 4151         N  Tienen mucho que mejorar en su atención al cli...       0
# 687          P                                           muy bien       1
# 3163         P         Recomendaría este lugar a todos mis amigos       1
# 4006         P         Gran trabajo, seguiré confiando en ustedes       1
# 5251         P      La experiencia fue excelente, muy recomendada       1
# ...        ...                                                ...     ...
# 649          P                                 Buena información.       1
# 5108         N            El producto llegó tarde y en mal estado       0
# 2784       NEU              No tengo nada relevante que mencionar       2
# 2289         P              Excelente trabajo, muy bien explicado       1
# 4421         N  La atención fue deficiente y no cumplieron lo ...       0
#
# [3399 rows x 3 columns]

# %%
df_test
# Out:
#      polaridad                                           feedback  target
# 192        NEU  No puedo evaluar porque no adjuntado respuesta...       2
# 1491         P                                           Exelente       1
# 3373         P         Gran trabajo, seguiré confiando en ustedes       1
# 4924         P                   El equipo funciona perfectamente       1
# 1545         P  Realizó un buen trabajo, pero debo resaltar qu...       1
# ...        ...                                                ...     ...
# 5011         P      La experiencia fue excelente, muy recomendada       1
# 2588         N  Se pudo haber esforzado al menos un poco. Deci...       0
# 2506         P                                           perfecto       1
# 3789       NEU              Cumple con lo básico, pero no destaca       2
# 2677         P  Todo funcionó perfectamente, gracias por el se...       1
#
# [2267 rows x 3 columns]

# %%
# Vectorizacion de palabras con un maximo de 1400
vectorizer = TfidfVectorizer(max_features=1368)

# %%
X_train = vectorizer.fit_transform(df_train['feedback'])
X_train
# Out:
# <3399x1368 sparse matrix of type '<class 'numpy.float64'>'
# 	with 23364 stored elements in Compressed Sparse Row format>

# %%
X_test = vectorizer.fit_transform(df_test['feedback'])
X_test
# Out:
# <2267x1368 sparse matrix of type '<class 'numpy.float64'>'
# 	with 15735 stored elements in Compressed Sparse Row format>

# %%
y_train = df_train['polaridad']
y_test = df_test['polaridad']

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
print("Train acc: ", model.score(X_train, y_train))
print("Test acc: ", model.score(X_test, y_test))
# Out:
# Train acc:  0.9532215357458076
# Test acc:  0.47154830172033524

# %%
P_train = model.predict(X_train)
P_test = model.predict(X_test)

# %%
cm = confusion_matrix(y_train, P_train, normalize='true')
cm
# Out:
# array([[0.96390658, 0.01380042, 0.02229299],
#        [0.05426357, 0.86821705, 0.07751938],
#        [0.00594177, 0.0077243 , 0.98633393]])

# %%
def plot_cm(cm):
    classes = ['negativo', 'positivo', 'neutral']
    df_cm = pd.DataFrame(cm, index=classes, columns=classes)
    ax = sn.heatmap(df_cm, annot=True, fmt='g')
    ax.set_xlabel("Predicción")
    ax.set_ylabel("Objetivo")

plot_cm(cm)

# %%
cm = confusion_matrix(y_test, P_test, normalize='true')
plot_cm(cm)

# %%
word_index_map = vectorizer.vocabulary_
word_index_map
# Out:
# {'excelente': 447,
#  'trabajo': 1243,
#  'éxitos': 1366,
#  'en': 388,
#  'este': 431,
#  'curso': 293,
#  'perfecto': 775,
#  'el': 377,
#  'diseño': 363,
#  'de': 301,
#  'la': 563,
#  'infografia': 542,
#  'es': 407,
#  'llamativa': 579,
#  'bien': 77,
#  'ordenada': 713,
#  'que': 939,
#  'motiva': 617,
#  'leer': 570,
#  'su': 1154,
#  'contenido': 224,
#  'buena': 81,
#  'presentacion': 866,
#  'felicidades': 471,
#  'compañero': 138,
#  'saludos': 1074,
#  'del': 316,
#  'tena': 1201,
#  'verdad': 1320,
#  'un': 1273,
#  'buen': 80,
#  'se': 1078,
#  'merece': 604,
#  'esa': 408,
#  'calificación': 89,
#  'porque': 835,
#  'fue': 485,
#  'una': 1274,
#  'las': 566,
#  'principales': 881,
#  'comunidad': 166,
#  'comunicativa': 165,
#  'no': 657,
#  'puede': 923,
#  'ver': 1319,
#  'debido': 308,
#  'calidad': 88,
#  'imagen': 528,
#  'revisar': 1051,
#  'por': 832,
#  'favor': 470,
#  'me': 597,
#  'gusto': 497,
#  'mucho': 623,
#  'como': 129,
#  'ha': 499,
#  'resumido': 1045,
#  'los': 586,
#  'aspectos': 58,
#  'mas': 594,
#  'microorganismos': 606,
#  'concuerdo': 184,
#  'con': 170,
#  'te': 1194,
#  'propuesto': 903,
#  'esta': 425,
#  'está': 442,
#  'adjunta': 16,
#  'él': 1364,
#  'cometiendo': 127,
#  'error': 406,
#  'unir': 1277,
#  'mismo': 611,
#  'tratamiento': 1251,
#  'sabemos': 1064,
#  'al': 25,
#  'parecer': 743,
#  'esto': 434,
#  'nos': 665,
#  'permite': 780,
#  'hacer': 504,
#  'seguimiento': 1084,
#  'más': 632,
#  'tabla': 1181,
#  'pero': 783,
#  'estructura': 438,
#  'utilizar': 1296,
#  'datos': 300,
#  'para': 740,
#  'tablas': 1182,
#  'gráficos': 495,
#  'resumen': 1044,
#  'todo': 1231,
#  'claro': 108,
#  'muy': 628,
#  'presentó': 873,
#  'juicio': 561,
#  'crítico': 278,
#  'excede': 446,
#  'requisitos': 1023,
#  'reto': 1048,
#  'realizó': 968,
#  'análisis': 40,
#  'solicitó': 1139,
#  'general': 488,
#  'correcto': 252,
#  'escritura': 410,
#  'correcta': 249,
#  'existe': 452,
#  'ortográficos': 730,
#  'solo': 1141,
#  'era': 405,
#  'copiar': 247,
#  'link': 577,
#  'formulario': 481,
#  'información': 546,
#  'pudo': 921,
#  'ser': 1095,
#  'través': 1254,
#  'solicita': 1132,
#  'subido': 1155,
#  'completa': 143,
#  'demasiado': 317,
#  'simple': 1117,
#  'realizar': 965,
#  'lectura': 569,
#  'comprensiva': 158,
#  'respuestas': 1037,
#  'hay': 509,
#  'ninguna': 653,
#  'presentación': 867,
#  'aporte': 45,
#  'tiene': 1221,
#  'relación': 1007,
#  'tema': 1197,
#  'necesita': 646,
#  'mejorar': 600,
#  'pedido': 759,
#  'infografía': 543,
#  'algunos': 30,
#  'técnicos': 1266,
#  'contenidos': 225,
#  'exelearning': 450,
#  'adecuada': 10,
#  'apoyo': 46,
#  'vida': 1325,
#  'profesional': 893,
#  'hoy': 519,
#  'dia': 348,
#  'necesarias': 641,
#  'muchos': 624,
#  'elemento': 381,
#  'olvido': 700,
#  'colocar': 115,
#  'aplicación': 43,
#  'utiliza': 1292,
#  'informacion': 545,
#  'póngale': 937,
#  'puntos': 932,
#  'gracias': 491,
#  'todas': 1230,
#  'personas': 787,
#  'práctica': 912,
#  'hasta': 508,
#  'perfección': 772,
#  'mi': 605,
#  'compañera': 137,
#  'enfocado': 393,
#  'explica': 457,
#  'flujo': 476,
#  'comunicación': 164,
#  'ni': 651,
#  'proceso': 889,
#  'control': 240,
#  'lo': 583,
#  'nombra': 658,
#  'realizo': 967,
#  'video': 1326,
#  'inicio': 547,
#  'texto': 1214,
#  'sobre': 1126,
#  'confusión': 196,
#  'presentadas': 869,
#  'material': 595,
#  'facilitaron': 463,
#  'aparte': 42,
#  'usted': 1287,
#  'investigado': 556,
#  'le': 568,
#  'siga': 1107,
#  'adelante': 12,
#  'tu': 1258,
#  'corresponde': 256,
#  'tarea': 1192,
#  'enviada': 403,
#  'acuerdo': 9,
#  'opinión': 704,
#  'hecho': 511,
#  'segunda': 1085,
#  'parte': 748,
#  'acerca': 3,
#  'también': 1187,
#  'visualizar': 1336,
#  'prototipo': 905,
#  'todos': 1232,
#  'criterios': 272,
#  'aprendiendo': 48,
#  'bendiciones': 71,
#  'analisis': 37,
#  'caso': 98,
#  'falto': 468,
#  'día': 372,
#  'ánimo': 1361,
#  'continuar': 232,
#  'bibliografías': 74,
#  'felicitaciones': 472,
#  'bueno': 83,
#  've': 1311,
#  'cortometraje': 262,
#  'espero': 423,
#  'puntaje': 930,
#  'falta': 464,
#  'mayor': 596,
#  'interpretar': 553,
#  'mejor': 599,
#  'problema': 887,
#  'sus': 1172,
#  'son': 1147,
#  'simples': 1118,
#  'poco': 818,
#  'nada': 637,
#  'responde': 1034,
#  'parece': 742,
#  'hace': 503,
#  'investigación': 555,
#  'poder': 820,
#  'completar': 146,
#  'preguntas': 858,
#  'llamo': 581,
#  'atención': 60,
#  'youtube': 1357,
#  'exitos': 455,
#  'utilizo': 1297,
#  'buenas': 82,
#  'fuentes': 486,
#  'cuales': 283,
#  'pregunta': 857,
#  'poner': 828,
#  'perciben': 768,
#  'manera': 592,
#  'negativa': 648,
#  'conflicto': 188,
#  'tenían': 1207,
#  'habría': 502,
#  'buscado': 85,
#  'similitudes': 1116,
#  'diferencias': 360,
#  'entre': 400,
#  'dos': 369,
#  'teorías': 1209,
#  'quede': 941,
#  'comentario': 125,
#  'sería': 1098,
#  'tamaño': 1186,
#  'letra': 573,
#  'igual': 527,
#  'numeros': 676,
#  'xy': 1353,
#  'obtener': 690,
#  'simetría': 1114,
#  'faltó': 469,
#  'estrategias': 437,
#  'cumple': 289,
#  'requerimientos': 1021,
#  'presente': 871,
#  'verificar': 1321,
#  'antes': 39,
#  'cuestionario': 287,
#  'solicitadas': 1134,
#  'abiertas': 2,
#  'cerradas': 100,
#  'observación': 685,
#  'relacionada': 1005,
#  'marca': 593,
#  'muchas': 622,
#  'creo': 269,
#  'debió': 309,
#  'qué': 949,
#  'preferencia': 855,
#  'piden': 796,
#  'descripción': 324,
#  'debería': 307,
#  'decir': 312,
#  'máximo': 634,
#  'ya': 1354,
#  'tabulación': 1183,
#  'complicada': 150,
#  'menos': 602,
#  'compañer': 136,
#  'encontrar': 389,
#  'nombre': 659,
#  'aun': 61,
#  'suerte': 1158,
#  'good': 490,
#  'recomienda': 979,
#  'nuevamente': 673,
#  'pueda': 922,
#  'requerida': 1017,
#  'pues': 927,
#  'estaba': 426,
#  'privado': 883,
#  'sé': 1177,
#  'específico': 422,
#  'tiempo': 1220,
#  'tenias': 1206,
#  'dibujo': 352,
#  'requerido': 1019,
#  'puedo': 926,
#  'sele': 1088,
#  'exelente': 451,
#  'visualiza': 1334,
#  'realizada': 960,
#  'hola': 518,
#  'has': 507,
#  'cumplido': 290,
#  'solicitada': 1133,
#  'sin': 1119,
#  'embargo': 383,
#  'textos': 1215,
#  'tipo': 1226,
#  'utilizados': 1293,
#  'quizá': 948,
#  'hubiese': 522,
#  'sido': 1102,
#  'enviar': 404,
#  'archivo': 53,
#  'adjunto': 17,
#  'presenta': 865,
#  'solicitado': 1135,
#  'concisas': 177,
#  'claras': 106,
#  'momento': 615,
#  'determinar': 346,
#  'solución': 1146,
#  'ahí': 23,
#  'donde': 368,
#  'debe': 302,
#  'podría': 824,
#  'proponer': 899,
#  'idea': 524,
#  'ambas': 34,
#  'partes': 749,
#  '50': 1,
#  'aportación': 44,
#  'ok': 699,
#  'coherente': 112,
#  'compara': 132,
#  'características': 92,
#  'teoría': 1208,
#  'observadas': 686,
#  'niño': 655,
#  'años': 65,
#  'si': 1101,
#  'tilda': 1224,
#  'palabras': 739,
#  'tener': 1203,
#  'criterio': 271,
#  'unas': 1275,
#  'sí': 1178,
#  'otras': 732,
#  'tildadas': 1225,
#  'refiero': 996,
#  'elementos': 382,
#  'misión': 608,
#  'visión': 1331,
#  'foda': 477,
#  'uno': 1280,
#  'oportunidad': 706,
#  'cada': 87,
#  'hizo': 516,
#  'organización': 720,
#  'ensayo': 395,
#  'ideas': 525,
#  'creativas': 265,
#  'interesante': 550,
#  'producción': 891,
#  'rango': 952,
#  'reúne': 1055,
#  'necesarios': 643,
#  'explicar': 459,
#  'puesto': 928,
#  'partir': 750,
#  'nueva': 672,
#  'pudiera': 920,
#  'necesidad': 644,
#  'oportunidades': 707,
#  'detalló': 345,
#  'existen': 453,
#  'dentro': 319,
#  'mercado': 603,
#  'puedes': 925,
#  'creatividad': 266,
#  'innovación': 548,
#  'próxima': 913,
#  'actores': 8,
#  'pueden': 924,
#  'estar': 430,
#  'indirectamente': 540,
#  'tipos': 1227,
#  'conflictos': 189,
#  'estos': 435,
#  'percibendebe': 769,
#  'intereses': 551,
#  'preocupaciones': 860,
#  'wow': 1351,
#  'super': 1165,
#  'foto': 482,
#  'tanto': 1190,
#  'tampoco': 1188,
#  'incluye': 534,
#  'adicional': 15,
#  'contradictoria': 235,
#  'evaluación': 444,
#  'pares': 747,
#  'pide': 795,
#  'aquí': 51,
#  'pidió': 798,
#  'instrucciones': 549,
#  'doy': 370,
#  'máxima': 633,
#  'puntuación': 933,
#  'aspecto': 57,
#  'estimada': 432,
#  'cuento': 286,
#  'pertinente': 790,
#  'niños': 656,
#  'primera': 877,
#  'pude': 919,
#  'terminar': 1213,
#  'web': 1346,
#  'observa': 684,
#  'actividad': 5,
#  'identificar': 526,
#  'desarrollo': 322,
#  'técnica': 1265,
#  'pni': 815,
#  'acorde': 4,
#  'formato': 480,
#  'encuesta': 392,
#  'herramientas': 513,
#  'goconqr': 489,
#  'incluir': 533,
#  'especifico': 421,
#  'laudo': 567,
#  'arbitral': 52,
#  'motivado': 618,
#  'solucionando': 1144,
#  'lamentablemente': 565,
#  'cuenta': 285,
#  'toma': 1233,
#  'seria': 1096,
#  'cierto': 101,
#  'debemos': 303,
#  'considerar': 209,
#  'dictado': 356,
#  'universidad': 1278,
#  'nivel': 654,
#  'utpl': 1300,
#  'leído': 575,
#  'superficialmente': 1167,
#  'viene': 1327,
#  'desde': 327,
#  'planteado': 810,
#  'módulos': 635,
#  'conceptos': 172,
#  'bonito': 79,
#  'aunque': 62,
#  'otro': 733,
#  'fondo': 478,
#  'realiza': 958,
#  'sobrinos': 1128,
#  'recibir': 975,
#  'herencia': 512,
#  'así': 59,
#  'última': 1367,
#  'voluntad': 1341,
#  'padres': 736,
#  'podrán': 823,
#  'encuentra': 390,
#  'precisa': 850,
#  'recomendaría': 978,
#  'resumirla': 1047,
#  'preciso': 853,
#  'precisión': 852,
#  'están': 443,
#  'consigna': 211,
#  'obstante': 689,
#  'reglas': 1003,
#  'ortográficas': 729,
#  'manejo': 591,
#  'planos': 806,
#  'colores': 119,
#  'usados': 1283,
#  'contraste': 239,
#  'tan': 1189,
#  'legible': 571,
#  'completo': 148,
#  'felicito': 473,
#  'incompleto': 536,
#  'subió': 1157,
#  'rellenar': 1009,
#  'cuadros': 281,
#  'vacíos': 1302,
#  'imagenes': 529,
#  'claros': 109,
#  'precisos': 854,
#  'temática': 1200,
#  'trabajada': 1241,
#  'cumplio': 291,
#  'usa': 1281,
#  'comprensión': 159,
#  'punnet': 929,
#  'combinaciones': 123,
#  'correctos': 253,
#  'vídeo': 1345,
#  'pareció': 746,
#  'remedio': 1010,
#  'casero': 96,
#  'común': 169,
#  'receta': 974,
#  'destacó': 337,
#  'uso': 1285,
#  'usadas': 1282,
#  'seco': 1081,
#  'respuesta': 1036,
#  'planta': 807,
#  'agregar': 21,
#  'plantas': 808,
#  'origen': 725,
#  'país': 758,
#  'detalles': 344,
#  'publicaste': 918,
#  'personal': 785,
#  'jpg': 560,
#  'desperdicio': 334,
#  'comida': 128,
#  'vuelto': 1344,
#  'social': 1129,
#  'hogares': 517,
#  'restaurantes': 1038,
#  'desperdicia': 333,
#  'comprar': 153,
#  'justo': 562,
#  'restaurants': 1039,
#  'ofrecen': 698,
#  'mundial': 626,
#  'divertido': 364,
#  'semana': 1089,
#  'bonanza': 78,
#  'explicito': 460,
#  'descriptivo': 325,
#  'gráfica': 494,
#  'representa': 1012,
#  'precipitación': 849,
#  'explicación': 458,
#  'indica': 537,
#  'tienen': 1222,
#  'positivos': 841,
#  'redactar': 990,
#  'pasate': 754,
#  'yo': 1355,
#  'queria': 943,
#  'mostrar': 616,
#  'clara': 104,
#  'logro': 585,
#  'concreto': 182,
#  'ese': 412,
#  'eso': 415,
#  'respeto': 1033,
#  'cuanto': 284,
#  'preferencias': 856,
#  'importancia': 530,
#  'existir': 454,
#  'expuesto': 461,
#  'siempre': 1104,
#  'he': 510,
#  'escuchado': 411,
#  'mis': 607,
#  'crucigrama': 275,
#  'podemos': 819,
#  'notar': 668,
#  'entendido': 398,
#  'definiciones': 314,
#  'indicaciones': 538,
#  'very': 1323,
#  'recordar': 983,
#  'faltaron': 466,
#  'especificaciones': 419,
#  'porcentajes': 833,
#  'agua': 22,
#  'ejemplos': 376,
#  'entrega': 401,
#  'referencia': 991,
#  'bibliográfica': 75,
#  'precisas': 851,
#  'posiciones': 839,
#  'compa': 130,
#  'escasa': 409,
#  'estudiante': 440,
#  'claramente': 105,
#  'problemas': 888,
#  'ubicadas': 1271,
#  'mucha': 621,
#  'correspondiente': 257,
#  'conforme': 190,
#  'parámetros': 751,
#  'establecidos': 428,
#  'publicada': 916,
#  'recalcar': 971,
#  'ciertos': 102,
#  'han': 506,
#  'tomado': 1234,
#  'encuentran': 391,
#  'descritos': 326,
#  'publicación': 915,
#  'misma': 609,
#  'pongo': 830,
#  'consideración': 207,
#  'dicha': 353,
#  'contiene': 230,
#  'establecido': 427,
#  'realizado': 961,
#  'describe': 323,
#  'habla': 501,
#  'objetivos': 681,
#  'empresa': 387,
#  'recurso': 987,
#  'planeación': 803,
#  'considero': 210,
#  'tus': 1260,
#  'actividades': 6,
#  'estan': 429,
#  'evidencia': 445,
#  'elaboración': 378,
#  'consiste': 214,
#  'diagrama': 349,
#  'ramificado': 951,
#  'historia': 515,
#  'probable': 885,
#  'grupo': 493,
#  'taxones': 1193,
#  'terminales': 1212,
#  'además': 14,
#  'cuál': 295,
#  'tomar': 1235,
#  'aire': 24,
#  'objetivo': 680,
#  'mal': 589,
#  'pedidos': 760,
#  'orden': 712,
#  'ana': 36,
#  'demás': 318,
#  'planes': 804,
#  'gran': 492,
#  'representación': 1014,
#  'hubiera': 521,
#  'perfecta': 773,
#  'desarrollado': 320,
#  'consisten': 215,
#  'concreta': 180,
#  'realizamos': 963,
#  'aquello': 50,
#  'relacionan': 1006,
#  'nuestras': 671,
#  'necesidades': 645,
#  'deseos': 329,
#  'organizadas': 721,
#  'forma': 479,
#  'conectores': 186,
#  'vocabulario': 1339,
#  'amplio': 35,
#  'pido': 799,
#  'comprension': 157,
#  'deber': 305,
#  'realidad': 957,
#  'contestado': 228,
#  'sigue': 1112,
#  'nice': 652,
#  'job': 559,
#  'combinación': 124,
#  'vegetales': 1313,
#  'subir': 1156,
#  'documento': 366,
#  'puntual': 934,
#  'medio': 598,
#  'alguna': 28,
#  'provincias': 908,
#  'ríos': 1061,
#  'emprendimiento': 386,
#  'sugiero': 1163,
#  'especificar': 420,
#  'considerando': 208,
#  'diferencia': 358,
#  'indirectos': 541,
#  'da': 298,
#  'veo': 1318,
#  'excelentes': 448,
#  'fotos': 484,
#  'permites': 782,
#  'consejo': 204,
#  'cuidado': 288,
#  'contra': 234,
#  'luz': 588,
#  'superaron': 1166,
#  'avanzado': 64,
#  'conocimientos': 203,
#  'bastante': 70,
#  'organizado': 722,
#  'letras': 574,
#  'pequeñas': 766,
#  'creativa': 264,
#  'resultar': 1042,
#  'confuso': 197,
#  'ángulo': 1359,
#  'muñecos': 630,
#  'solorzano': 1142,
#  'nunca': 677,
#  'recargue': 972,
#  'pagina': 737,
#  'volví': 1342,
#  'sesión': 1099,
#  'perjudicarla': 777,
#  'siguiente': 1113,
#  'nota': 666,
#  'ud': 1272,
#  'considera': 205,
#  'recomiendo': 980,
#  'ponga': 829,
#  'profesores': 894,
#  'desgraciadamente': 330,
#  'referencias': 992,
#  'bibliográficas': 76,
#  'entiende': 399,
#  'proxima': 909,
#  'coloco': 116,
#  'mundialmente': 627,
#  'reconocida': 982,
#  'esfuerzo': 413,
#  'postventa': 843,
#  'tecnología': 1195,
#  'servicio': 1097,
#  'vanguardia': 1308,
#  'confío': 198,
#  'hiciste': 514,
#  'interés': 554,
#  'raíz': 954,
#  'correctas': 251,
#  'llegar': 582,
#  'pragmátic': 848,
#  'propuestas': 902,
#  'planteadas': 809,
#  'temas': 1198,
#  'preparación': 863,
#  'sustrato': 1176,
#  'semillero': 1091,
#  'talvez': 1185,
#  'convendría': 242,
#  'infografías': 544,
#  'aparece': 41,
#  'enlace': 394,
#  'motivo': 619,
#  'numeración': 674,
#  'entendible': 397,
#  'procesos': 890,
#  'utilidades': 1291,
#  'contraindicaciones': 236,
#  'toque': 1238,
#  'creativo': 267,
#  'trbajo': 1255,
#  'trabajó': 1246,
#  'redacción': 989,
#  'requeridos': 1020,
#  'original': 726,
#  'llamativo': 580,
#  'oportunamente': 705,
#  'espacio': 416,
#  'plano': 805,
#  'resto': 1040,
#  'presentado': 870,
#  'detallado': 340,
#  'soy': 1152,
#  'ubicada': 1270,
#  'provincia': 907,
#  'ciudad': 103,
#  'portoviejo': 836,
#  'nuestra': 670,
#  'solicitados': 1136,
#  'cordiales': 248,
#  'luchar': 587,
#  'prejuicios': 859,
#  'ánimos': 1362,
#  'vencerlos': 1317,
#  'logra': 584,
#  'reconocer': 981,
#  'diferenciar': 359,
#  'posición': 840,
#  'compraracion': 154,
#  'primer': 876,
#  'tenia': 1205,
#  'vincular': 1328,
#  'analizar': 38,
#  'comparar': 135,
#  'ustedes': 1288,
#  'observan': 687,
#  'deben': 304,
#  'observar': 688,
#  'tres': 1256,
#  'contexto': 229,
#  'área': 1363,
#  'pensamiento': 764,
#  'motricidad': 620,
#  'lenguaje': 572,
#  'socioafectiva': 1130,
#  'composición': 152,
#  'entender': 396,
#  'compita': 142,
#  'base': 69,
#  'ortografía': 728,
#  'nombres': 660,
#  'completos': 149,
#  'pertenece': 789,
#  'sólo': 1180,
#  'work': 1350,
#  'detallas': 342,
#  'signos': 1111,
#  'deberias': 306,
#  'usar': 1284,
#  'coma': 121,
#  'punto': 931,
#  'algunas': 29,
#  'oraciones': 709,
#  'pedìa': 761,
#  'soporte': 1150,
#  'refiere': 994,
#  'cumplió': 292,
#  'desarrollar': 321,
#  'imágenes': 532,
#  'picado': 794,
#  'sujeto': 1164,
#  'requiere': 1022,
#  'otra': 731,
#  'preparacion': 862,
#  'sencilla': 1092,
#  'relacion': 1004,
#  'totalidad': 1239,
#  'diferentes': 361,
#  'trabajos': 1245,
#  'tal': 1184,
#  'resumir': 1046,
#  'mismas': 610,
#  'tardes': 1191,
#  'estimado': 433,
#  'afectadas': 19,
#  'negociacion': 649,
#  'basada': 68,
#  'unasolucion': 1276,
#  'respaldo': 1030,
#  'después': 335,
#  'detalla': 338,
#  'indicar': 539,
#  'segundos': 1086,
#  'poca': 817,
#  'realización': 959,
#  'solucionan': 1143,
#  'aprende': 47,
#  'utilizó': 1298,
#  'reales': 956,
#  'sugiere': 1162,
#  'utilice': 1290,
#  'argumentación': 54,
#  'resalta': 1024,
#  'excellent': 449,
#  'estrategia': 436,
#  'parecido': 744,
#  'saludo': 1073,
#  'yovanny': 1358,
#  'supo': 1169,
#  'practico': 847,
#  'debía': 311,
#  'realizarse': 966,
#  'elaborado': 380,
#  'satisfactoriamente': 1077,
#  'adecuadamente': 11,
#  'vbien': 1310,
#  'sugerencia': 1160,
#  'utlizar': 1299,
#  'claves': 110,
#  'vamos': 1307,
#  'casi': 97,
#  'mitad': 612,
#  'podía': 827,
#  'poniendo': 831,
#  'practica': 845,
#  'importante': 531,
#  'alimento': 32,
#  'tratado': 1250,
#  'respecto': 1031,
#  'tratar': 1252,
#  'really': 969,
#  'completed': 147,
#  'estuvo': 441,
#  'referente': 993,
#  'créditos': 277,
#  'coloqué': 117,
#  'valeria': 1304,
#  'próximo': 914,
#  'podrías': 826,
#  'color': 118,
#  'detallar': 341,
#  'propiedades': 898,
#  'usos': 1286,
#  'producto': 892,
#  'organela': 714,
#  'puso': 936,
#  'comparación': 134,
#  'organelas': 715,
#  'algún': 31,
#  'objeto': 682,
#  'según': 1087,
#  'pidiendo': 797,
#  'compresión': 160,
#  'primerísimo': 878,
#  'contrapicado': 237,
#  'dadas': 299,
#  'principalmente': 882,
#  'mala': 590,
#  'vehiculo': 1314,
#  'efectos': 374,
#  'oyente': 735,
#  'sordo': 1151,
#  'rápidamente': 1060,
#  'vez': 1324,
#  'conversación': 243,
#  'normal': 662,
#  'investigar': 557,
#  'cursos': 294,
#  'ofertan': 696,
#  'haciendo': 505,
#  'crisfe': 270,
#  'pnud': 816,
#  'señala': 1100,
#  'sector': 1082,
#  'ofrece': 697,
#  'otros': 734,
#  'alcance': 26,
#  'nacional': 636,
#  'the': 1216,
#  'word': 1349,
#  'normas': 664,
#  'vista': 1332,
#  'destaca': 336,
#  'detalle': 343,
#  'preparar': 864,
#  'dieran': 357,
#  'sienten': 1105,
#  'confusa': 195,
#  'tribunal': 1257,
#  'va': 1301,
#  'menciona': 601,
#  'afectación': 18,
#  'sale': 1069,
#  'sencillo': 1093,
#  'títulos': 1269,
#  'visiones': 1330,
#  'haber': 500,
#  'argumentos': 55,
#  'función': 487,
#  'naturalista': 639,
#  'preserva': 874,
#  'sustenta': 1174,
#  'llama': 578,
#  'publicapuede': 917,
#  'competo': 141,
#  'responder': 1035,
#  'propuesta': 901,
#  'buenos': 84,
#  'pequeño': 767,
#  'cuadro': 280,
#  'especie': 418,
#  'carece': 93,
#  'patas': 756,
#  'designados': 331,
#  'costos': 263,
#  'critica': 273,
#  'consideraciones': 206,
#  'màs': 631,
#  'revisado': 1049,
#  'ochoa': 694,
#  'profundizar': 895,
#  'elaborada': 379,
#  ...}

# %%
model.coef_[0]
# Out:
# array([ 0.20246882, -0.11033645, -0.17585563, ...,  0.32638359,
#        -0.1526226 , -0.1997816 ])

# %%
corte = 0.8

print("Palabras más positivas:")
for word, index in word_index_map.items():
    weight = model.coef_[0][index]
    if weight > corte:
        print(word, weight)
# Out:
# Palabras más positivas:
# información 1.770941926369859
# personas 4.235671709207172
# inicio 0.8361334683285024
# negativa 0.974922054736559
# entrega 0.9065437821932535
# mucha 0.981234782696943
# diferentes 1.039344424526437
# notable 0.9045053052097572

# %%
plt.hist(model.coef_[0], bins=100);

# %%
corte = 0.7

print("Palabras más positivas:")
for word, index in word_index_map.items():
    weight = model.coef_[0][index]
    if weight < -corte:
        print(word, weight)
# Out:
# Palabras más positivas:
# usted -0.762890722420872
# empresa -0.8110654682444964
# combinación -1.508809879311905
# compita -1.1292994785226682
# investigar -0.7991743038679979
# competo -1.4623857310981594
# humorsé -1.718957750153572
# png -0.9738911652091224
# utilizan -0.7320032807617798
# percibir -1.1851883177957894
# ja -0.9980147982557914

# %%
# Prueba del modelo entrenado
prueba = ["Estuvo muy buena la pelicula", "estuvo terrible la pelicula, me aburrí mucho", "no la recomiendo", "Vi la pelicula"]

# %%
# Transformar la entrada con el vectorizador
X = vectorizer.transform(prueba)

# Predecir con el modelo
P = model.predict(X)

# Obtener las clases del modelo
clases = model.classes_

print(f"Longitud de P: {len(P)}")
print(f"Longitud de clases: {len(clases)}")

for i in range(len(prueba)):
    if i < len(clases) and i < len(P):  # Verificación de los límites
        if isinstance(P[i], int) and 0 <= P[i] < len(clases):  # Asegurar que P[i] es un índice válido
            if clases[P[i]] == 0:
                print(f"El comentario: '{prueba[i]}' es Negativo")
            else:
                print(f"El comentario: '{prueba[i]}' es Positivo")
        else:
            print(f"Índice inválido en P[{i}]: {P[i]}")
